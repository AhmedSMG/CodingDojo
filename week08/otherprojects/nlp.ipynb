# %%
import nltk

# %%
from google.colab import drive
drive.mount("./gdrive")
# Out:
# Mounted at ./gdrive

# %%
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> all
# ...
#        |
#        | Downloading package abc to /root/nltk_data...
#        |   Unzipping corpora/abc.zip.
#        | Downloading package alpino to /root/nltk_data...
#        |   Unzipping corpora/alpino.zip.
#        | Downloading package biocreative_ppi to /root/nltk_data...
#        |   Unzipping corpora/biocreative_ppi.zip.
#        | Downloading package brown to /root/nltk_data...
#        |   Unzipping corpora/brown.zip.
#        | Downloading package brown_tei to /root/nltk_data...
#        |   Unzipping corpora/brown_tei.zip.
#        | Downloading package cess_cat to /root/nltk_data...
#        |   Unzipping corpora/cess_cat.zip.
# ...

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
text7
# Out:
# <Text: Wall Street Journal>

# %%
text6
# Out:
# <Text: Monty Python and the Holy Grail>

# %%
text5
# Out:
# <Text: Chat Corpus>

# %%
from nltk.corpus import  brown

# %%
brown.categories()
# Out:
# ['adventure',
#  'belles_lettres',
#  'editorial',
#  'fiction',
#  'government',
#  'hobbies',
#  'humor',
#  'learned',
#  'lore',
#  'mystery',
#  'news',
#  'religion',
#  'reviews',
#  'romance',
#  'science_fiction']

# %%
brown.words(categories="hobbies")
# Out:
# ['Too', 'often', 'a', 'beginning', 'bodybuilder', ...]

# %%
from nltk.corpus import webtext

# %%
for fileid in webtext.fileids():
    print(fileid, webtext.raw(fileid)[:20], "...")
# Out:
# firefox.txt Cookie Manager: "Don ...
# grail.txt SCENE 1: [wind] [clo ...
# overheard.txt White guy: So, do yo ...
# pirates.txt PIRATES OF THE CARRI ...
# singles.txt 25 SEXY MALE, seeks  ...
# wine.txt Lovely delicate, fra ...

# %%
from nltk.corpus import inaugural

# %%
inaugural.fileids()
# Out:
# ['1789-Washington.txt',
#  '1793-Washington.txt',
#  '1797-Adams.txt',
#  '1801-Jefferson.txt',
#  '1805-Jefferson.txt',
#  '1809-Madison.txt',
#  '1813-Madison.txt',
#  '1817-Monroe.txt',
#  '1821-Monroe.txt',
#  '1825-Adams.txt',
#  '1829-Jackson.txt',
#  '1833-Jackson.txt',
#  '1837-VanBuren.txt',
#  '1841-Harrison.txt',
#  '1845-Polk.txt',
#  '1849-Taylor.txt',
#  '1853-Pierce.txt',
#  '1857-Buchanan.txt',
#  '1861-Lincoln.txt',
#  '1865-Lincoln.txt',
#  '1869-Grant.txt',
#  '1873-Grant.txt',
#  '1877-Hayes.txt',
#  '1881-Garfield.txt',
#  '1885-Cleveland.txt',
#  '1889-Harrison.txt',
#  '1893-Cleveland.txt',
#  '1897-McKinley.txt',
#  '1901-McKinley.txt',
#  '1905-Roosevelt.txt',
#  '1909-Taft.txt',
#  '1913-Wilson.txt',
#  '1917-Wilson.txt',
#  '1921-Harding.txt',
#  '1925-Coolidge.txt',
#  '1929-Hoover.txt',
#  '1933-Roosevelt.txt',
#  '1937-Roosevelt.txt',
#  '1941-Roosevelt.txt',
#  '1945-Roosevelt.txt',
#  '1949-Truman.txt',
#  '1953-Eisenhower.txt',
# ...

# %%
from nltk.corpus import stopwords

# %%
stop_words = stopwords.words("english")

# %%
path = "./gdrive/MyDrive/datasets/ANC_MASC/data/written/twitter/tweets1.txt"

# %%
with open(path, mode="r") as fp:
    text = fp.read()
    text = text.split()
text[0:30]
# Out:
# ['just',
#  'setting',
#  'up',
#  'my',
#  'twttr',
#  'tm',
#  'help',
#  'Wondering',
#  'if',
#  'I',
#  'should',
#  'quit',
#  'work',
#  'and',
#  'become',
#  'a',
#  'monk',
#  'who',
#  'secretly',
#  'writes',
#  'serial',
#  'murder',
#  'thriller',
#  'novels.',
#  'Going',
#  'to',
#  'bed.',
#  'gary',
#  'coleman',
#  'sighting']

# %%
abstracts = nltk.Text(text)

# %%
abstracts.concordance("luck")
# Out:
# Displaying 2 of 2 matches:
#  Signal premiere. Lotsa buyers. Good luck gang listening to the pocast net@nit
# t I can throw farther than her. Good luck with that dude. Sure it will all be

# %% [markdown]
# # Conditional Frequency Distribution

# %%
from nltk.book import  *

# %%
fdist = FreqDist(text1)

# %%
fdist
# Out:
# FreqDist({'[': 3,
#           'Moby': 84,
#           'Dick': 84,
#           'by': 1137,
#           'Herman': 1,
#           'Melville': 1,
#           '1851': 3,
#           ']': 1,
#           'ETYMOLOGY': 1,
#           '.': 6862,
#           '(': 210,
#           'Supplied': 2,
#           'a': 4569,
#           'Late': 1,
#           'Consumptive': 1,
#           'Usher': 2,
#           'to': 4542,
#           'Grammar': 2,
#           'School': 1,
#           ')': 78,
#           'The': 612,
#           'pale': 18,
#           '--': 1070,
#           'threadbare': 1,
#           'in': 3916,
#           'coat': 28,
#           ',': 18713,
#           'heart': 90,
#           'body': 110,
#           'and': 6024,
#           'brain': 37,
#           ';': 4072,
#           'I': 2124,
#           'see': 253,
#           'him': 1058,
#           'now': 646,
#           'He': 230,
#           'was': 1632,
#           'ever': 203,
#           'dusting': 2,
#           'his': 2459,
# ...

# %%
fdist.most_common(25)
# Out:
# [(',', 18713),
#  ('the', 13721),
#  ('.', 6862),
#  ('of', 6536),
#  ('and', 6024),
#  ('a', 4569),
#  ('to', 4542),
#  (';', 4072),
#  ('in', 3916),
#  ('that', 2982),
#  ("'", 2684),
#  ('-', 2552),
#  ('his', 2459),
#  ('it', 2209),
#  ('I', 2124),
#  ('s', 1739),
#  ('is', 1695),
#  ('he', 1661),
#  ('with', 1659),
#  ('was', 1632),
#  ('as', 1620),
#  ('"', 1478),
#  ('all', 1462),
#  ('for', 1414),
#  ('this', 1280)]

# %%
fdist.plot(50, cumulative=True)

# %%
print(fdist)
# Out:
# <FreqDist with 19317 samples and 260819 outcomes>

# %%
from nltk.probability import ConditionalFreqDist

# %%
cfdist = ConditionalFreqDist([(len(word), word) for word in text])

# %%
cfdist
# Out:
# ConditionalFreqDist(nltk.probability.FreqDist,
#                     {1: FreqDist({'!': 1,
#                                '"': 1,
#                                '&': 7,
#                                '+': 1,
#                                ',': 2,
#                                '-': 39,
#                                '.': 12,
#                                '1': 8,
#                                '2': 15,
#                                '3': 12,
#                                '4': 1,
#                                '5': 3,
#                                '6': 3,
#                                '7': 2,
#                                '8': 1,
#                                ':': 6,
#                                '=': 2,
#                                '?': 1,
#                                '@': 4,
#                                'A': 13,
#                                'I': 153,
#                                'K': 1,
# ...

# %%
cfdist[3]
# Out:
# FreqDist({'"An': 1,
#           '"UB': 1,
#           "'An": 1,
#           "'LA": 1,
#           "'em": 3,
#           '(28': 1,
#           '(Hi': 1,
#           '(L)': 1,
#           '(ex': 1,
#           '(we': 1,
#           '-a:': 1,
#           '...': 20,
#           '..I': 1,
#           '0.2': 2,
#           '101': 1,
#           '102': 1,
#           '11.': 1,
#           '1st': 1,
#           '2.0': 3,
#           '2/3': 1,
#           '243': 1,
#           '24c': 1,
#           '25!': 1,
#           '2am': 1,
#           '2nd': 3,
#           '3.0': 2,
#           '3/4': 1,
#           '322': 1,
#           '340': 1,
#           '386': 1,
#           '405': 1,
#           '50%': 1,
#           '500': 1,
#           '70+': 2,
#           '7am': 1,
#           '808': 1,
#           '8Am': 1,
#           '9EG': 1,
#           ':)\\': 1,
#           ':-(': 1,
#           ':-)': 4,
#           ':0o': 1,
#           ';-)': 3,
#           '???': 1,
#           'ACS': 1,
# ...

# %%
cfdist[5]
# Out:
# FreqDist({'"Away': 1,
#           '"Best': 1,
#           '"Turn': 1,
#           '"kill': 1,
#           '"see,': 1,
#           '$2.00': 1,
#           '$850m': 1,
#           "'Stay": 1,
#           "'bout": 1,
#           "'this": 1,
#           '(Baby': 1,
#           "(I've": 1,
#           '(Open': 1,
#           '(aka,': 1,
#           '(like': 1,
#           '0430.': 1,
#           '10pm.': 2,
#           '125th': 1,
#           '14:36': 1,
#           '16-0.': 1,
#           '2007!': 1,
#           '6.170': 1,
#           'ANNA.': 1,
#           'ASAP.': 1,
#           'About': 4,
#           'Adobe': 1,
#           'After': 1,
#           'Alley': 1,
#           'Allow': 1,
#           'Alvin': 1,
#           'Amira': 1,
#           'Armin': 2,
#           'Audio': 2,
#           'BONES': 1,
#           'BRENT': 1,
#           'BUSH,': 1,
#           "Bags'": 1,
#           'Being': 1,
#           'Bingo': 1,
#           'Birch': 1,
#           'Black': 3,
# ...

# %% [markdown]
# # Lexical Resource

# %%
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
entries = nltk.corpus.cmudict.entries()
entries
# Out:
# [('a', ['AH0']), ('a.', ['EY1']), ('a', ['EY1']), ...]

# %%
len(entries)
# Out:
# 133737

# %%
for entry in entries[10000:10025]:
    print(entry)
# Out:
# ('belford', ['B', 'EH1', 'L', 'F', 'ER0', 'D'])
# ('belfry', ['B', 'EH1', 'L', 'F', 'R', 'IY0'])
# ('belgacom', ['B', 'EH1', 'L', 'G', 'AH0', 'K', 'AA0', 'M'])
# ('belgacom', ['B', 'EH1', 'L', 'JH', 'AH0', 'K', 'AA0', 'M'])
# ('belgard', ['B', 'EH0', 'L', 'G', 'AA1', 'R', 'D'])
# ('belgarde', ['B', 'EH0', 'L', 'G', 'AA1', 'R', 'D', 'IY0'])
# ('belge', ['B', 'EH1', 'L', 'JH', 'IY0'])
# ('belger', ['B', 'EH1', 'L', 'G', 'ER0'])
# ('belgian', ['B', 'EH1', 'L', 'JH', 'AH0', 'N'])
# ('belgians', ['B', 'EH1', 'L', 'JH', 'AH0', 'N', 'Z'])
# ('belgique', ['B', 'EH0', 'L', 'ZH', 'IY1', 'K'])
# ("belgique's", ['B', 'EH0', 'L', 'JH', 'IY1', 'K', 'S'])
# ('belgium', ['B', 'EH1', 'L', 'JH', 'AH0', 'M'])
# ("belgium's", ['B', 'EH1', 'L', 'JH', 'AH0', 'M', 'Z'])
# ('belgo', ['B', 'EH1', 'L', 'G', 'OW2'])
# ('belgrade', ['B', 'EH1', 'L', 'G', 'R', 'EY0', 'D'])
# ('belgrade', ['B', 'EH1', 'L', 'G', 'R', 'AA2', 'D'])
# ("belgrade's", ['B', 'EH1', 'L', 'G', 'R', 'EY0', 'D', 'Z'])
# ...

# %%
from nltk.corpus import wordnet as wn

# %%
wn.synsets("motorcar")
# Out:
# [Synset('car.n.01')]

# %%
wn.synset("car.n.01").lemma_names()
# Out:
# ['car', 'auto', 'automobile', 'machine', 'motorcar']

# %% [markdown]
# # Processing Raw Text

# %%
sample_text = ["""The Golden Retriever is a medium-large gun dog that was bred to retrieve shot waterfowl,
such as ducks and upland game birds, during hunting and shooting parties.
The name 'retriever' refers to the breed's ability to retrieve shot game undamaged due to their soft mouth.
Golden retrievers have an instinctive love of water, and are easy to train to basic or advanced obedience standards.
They are a long-coated breed, with a dense inner coat that provides them with adequate warmth in the outdoors,
and an outer coat that lies flat against their bodies and repels water.
Golden retrievers are well suited to residency in suburban or country environments.
They shed copiously, particularly at the change of seasons, and require fairly regular grooming.
The Golden Retriever was originally bred in Scotland in the mid-19th century."""]

# %%
print(sample_text)
# Out:
# ["The Golden Retriever is a medium-large gun dog that was bred to retrieve shot waterfowl,\nsuch as ducks and upland game birds, during hunting and shooting parties.\nThe name 'retriever' refers to the breed's ability to retrieve shot game undamaged due to their soft mouth.\nGolden retrievers have an instinctive love of water, and are easy to train to basic or advanced obedience standards.\nThey are a long-coated breed, with a dense inner coat that provides them with adequate warmth in the outdoors,\nand an outer coat that lies flat against their bodies and repels water.\nGolden retrievers are well suited to residency in suburban or country environments.\nThey shed copiously, particularly at the change of seasons, and require fairly regular grooming.\nThe Golden Retriever was originally bred in Scotland in the mid-19th century."]

# %%
for text in sample_text:
     sentances = nltk.sent_tokenize(text)
     for sentance in sentances:
         words = nltk.word_tokenize(sentance)
         tagged_words = nltk.pos_tag(words)
         ne_tagged_words = nltk.ne_chunk(tagged_words)
         print(ne_tagged_words)
# Out:
# (S
#   The/DT
#   (ORGANIZATION Golden/NNP)
#   Retriever/NNP
#   is/VBZ
#   a/DT
#   medium-large/JJ
#   gun/NN
#   dog/NN
#   that/WDT
#   was/VBD
#   bred/VBN
#   to/TO
#   retrieve/VB
#   shot/NN
#   waterfowl/NN
#   ,/,
#   such/JJ
#   as/IN
#   ducks/NNS
#   and/CC
#   upland/JJ
#   game/NN
#   birds/NNS
#   ,/,
#   during/IN
#   hunting/VBG
#   and/CC
#   shooting/VBG
#   parties/NNS
#   ./.)
# (S
#   The/DT
#   name/NN
#   'retriever/POS
#   '/POS
#   refers/NNS
#   to/TO
#   the/DT
#   breed/NN
#   's/POS
#   ability/NN
#   to/TO
#   retrieve/VB
#   shot/JJ
#   game/NN
#   undamaged/VBD
#   due/JJ
#   to/TO
#   their/PRP$
#   soft/JJ
#   mouth/NN
#   ./.)
# (S
#   (GPE Golden/NNP)
#   retrievers/NNS
#   have/VBP
#   an/DT
#   instinctive/JJ
#   love/NN
#   of/IN
#   water/NN
#   ,/,
#   and/CC
#   are/VBP
#   easy/JJ
#   to/TO
#   train/VB
#   to/TO
#   basic/VB
#   or/CC
#   advanced/JJ
#   obedience/NN
#   standards/NNS
#   ./.)
# (S
#   They/PRP
#   are/VBP
#   a/DT
# ...

# %%
text = "My dog got board, amd decidedd to chase our cat. So the cat jumped into my arms"

# %%
sent_text = nltk.tokenize.sent_tokenize(text)
sent_text
# Out:
# ['My dog got board, amd decidedd to chase our cat.',
#  'So the cat jumped into my arms']

# %%
words_text = nltk.tokenize.word_tokenize(text)
words_text
# Out:
# ['My',
#  'dog',
#  'got',
#  'board',
#  ',',
#  'amd',
#  'decidedd',
#  'to',
#  'chase',
#  'our',
#  'cat',
#  '.',
#  'So',
#  'the',
#  'cat',
#  'jumped',
#  'into',
#  'my',
#  'arms']

# %%
for sents in sent_text:
    token_text = nltk.word_tokenize(sents)
    print(token_text)
# Out:
# ['My', 'dog', 'got', 'board', ',', 'amd', 'decidedd', 'to', 'chase', 'our', 'cat', '.']
# ['So', 'the', 'cat', 'jumped', 'into', 'my', 'arms']

# %%
from nltk.tokenize import TweetTokenizer

# %%
text = "That party was sooooo fun! :D #superfun"
tknzr = TweetTokenizer()
tknzr.tokenize(text)
# Out:
# ['That', 'party', 'was', 'sooooo', 'fun', '!', ':D', '#superfun']

# %%
import re

# %%
ex = "The big yellow bird flow over my house"

# %%
def preprocess(sent):
    sent = nltk.tokenize.word_tokenize(sent)
    sent = nltk.pos_tag(sent)
    return sent

# %%
preprocess(ex)
# Out:
# [('The', 'DT'),
#  ('big', 'JJ'),
#  ('yellow', 'JJ'),
#  ('bird', 'NN'),
#  ('flow', 'NN'),
#  ('over', 'IN'),
#  ('my', 'PRP$'),
#  ('house', 'NN')]

# %%
np_rule = "NP: {<DT>?<JJ>*<NN>}"

# %%
cp = nltk.RegexpParser(np_rule)
cs = cp.parse(preprocess(ex))
print(cs)
# Out:
# (S
#   (NP The/DT big/JJ yellow/JJ bird/NN)
#   (NP flow/NN)
#   over/IN
#   my/PRP$
#   (NP house/NN))

# %%
reg_rule = """
    NP: {<DT>?<JJ>*<NN>}
        {<NNP>+}
"""

# %%
cp = nltk.RegexpParser(reg_rule)
cs = cp.parse(preprocess(ex))
print(cs)
# Out:
# (S
#   (NP The/DT big/JJ yellow/JJ bird/NN)
#   (NP flow/NN)
#   over/IN
#   my/PRP$
#   (NP house/NN))

# %% [markdown]
# # Text Classfication

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> all
# ...
#        |
#        | Downloading package abc to /root/nltk_data...
#        |   Unzipping corpora/abc.zip.
#        | Downloading package alpino to /root/nltk_data...
#        |   Unzipping corpora/alpino.zip.
#        | Downloading package biocreative_ppi to /root/nltk_data...
#        |   Unzipping corpora/biocreative_ppi.zip.
#        | Downloading package brown to /root/nltk_data...
#        |   Unzipping corpora/brown.zip.
#        | Downloading package brown_tei to /root/nltk_data...
#        |   Unzipping corpora/brown_tei.zip.
#        | Downloading package cess_cat to /root/nltk_data...
#        |   Unzipping corpora/cess_cat.zip.
# ...

# %%
def gender_features(word):
    return {"last_letter": word[-1]}

# %%
from nltk.corpus import names

# %%
labeled_names = ([(name, "male") for name in names.words("male.txt")] +
                 [(name, "female") for name in names.words("female.txt")])

# %%
import random

# %%
random.shuffle(labeled_names)

# %%
labeled_names
# Out:
# [('Chrissie', 'female'),
#  ('Demetria', 'female'),
#  ('Neilla', 'female'),
#  ('Rhett', 'male'),
#  ('Suzette', 'female'),
#  ('Skippy', 'male'),
#  ('Wald', 'male'),
#  ('Tailor', 'male'),
#  ('Alpa', 'female'),
#  ('Thain', 'male'),
#  ('Thornie', 'male'),
#  ('Dorelle', 'female'),
#  ('Matti', 'female'),
#  ('Alida', 'female'),
#  ('Ulick', 'male'),
#  ('Isobel', 'female'),
#  ('Janelle', 'female'),
#  ('Elvis', 'male'),
#  ('Vanya', 'female'),
#  ('Debee', 'female'),
#  ('Eleni', 'female'),
#  ('Shelbi', 'female'),
#  ('Immanuel', 'male'),
#  ('Beatrisa', 'female'),
#  ('Murielle', 'female'),
#  ('Roxi', 'female'),
#  ('Ilise', 'female'),
#  ('Roch', 'female'),
#  ('Cecelia', 'female'),
#  ('Locke', 'male'),
#  ('Felix', 'male'),
#  ('Andrea', 'male'),
#  ('Nata', 'female'),
#  ('Alfonzo', 'male'),
#  ('Floyd', 'male'),
#  ('Enid', 'female'),
#  ('Elberta', 'female'),
#  ('Fletcher', 'male'),
#  ('Moyna', 'female'),
#  ('Angel', 'female'),
#  ('Kirk', 'male'),
# ...

# %%
features = [(gender_features(name), gender) for (name, gender) in labeled_names]

# %%
features
# Out:
# [({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'k'}, 'male'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
# ...

# %%
train ,test = features[500:], features[:500]

# %%
naive_cls = nltk.NaiveBayesClassifier.train(train)

# %%
naive_cls.classify(gender_features("David"))
# Out:
# 'male'

# %%
nltk.classify.accuracy(naive_cls, test)
# Out:
# 0.768

# %%
from nltk.tokenize.casual import EMOTICON_RE

# %%
def get_features(message):
    emoticon = EMOTICON_RE.findall(' '.join(message))

    if not emoticon: emoticon = 0
    else: emoticon = 1

    lenght = len(message)
    return {
        "Emoticon": emoticon,
        "Lenght": lenght
    }

# %%
from nltk.corpus import nps_chat

# %%
chat_room_20 = nps_chat.posts("10-19-20s_706posts.xml")
chat_room_30 = nps_chat.posts("10-19-30s_705posts.xml")
chat_room_40 = nps_chat.posts("10-19-40s_686posts.xml")

# %%
chat_room_40[54]
# Out:
# ['sometimes',
#  'depending',
#  'on',
#  'the',
#  'book',
#  '...',
#  'ya',
#  'just',
#  'wanna',
#  'leave',
#  'that',
#  'chapter',
#  'out',
#  'and',
#  'make',
#  'it',
#  'a',
#  'mystery']

# %%
labeled_chats = ([(post, "20s") for post in chat_room_20] + 
                [(post, "30s") for post in chat_room_30] + 
                [(post, "40s") for post in chat_room_40])

# %%
labeled_chats[54]
# Out:
# (['26', '/', 'm'], '20s')

# %%
import random

# %%
random.shuffle(labeled_chats)
features = [(get_features(x), age) for (x, age) in labeled_chats]
train, test = features[:500], features[500:]

# %%
train
# Out:
# [({'Emoticon': 0, 'Lenght': 1}, '40s'),
#  ({'Emoticon': 0, 'Lenght': 1}, '40s'),
#  ({'Emoticon': 0, 'Lenght': 6}, '30s'),
#  ({'Emoticon': 0, 'Lenght': 7}, '30s'),
#  ({'Emoticon': 0, 'Lenght': 6}, '40s'),
#  ({'Emoticon': 0, 'Lenght': 2}, '30s'),
#  ({'Emoticon': 0, 'Lenght': 2}, '30s'),
#  ({'Emoticon': 0, 'Lenght': 13}, '40s'),
#  ({'Emoticon': 0, 'Lenght': 4}, '30s'),
#  ({'Emoticon': 0, 'Lenght': 2}, '40s'),
#  ({'Emoticon': 0, 'Lenght': 9}, '20s'),
#  ({'Emoticon': 0, 'Lenght': 2}, '30s'),
#  ({'Emoticon': 0, 'Lenght': 10}, '40s'),
#  ({'Emoticon': 0, 'Lenght': 5}, '20s'),
#  ({'Emoticon': 0, 'Lenght': 2}, '40s'),
#  ({'Emoticon': 0, 'Lenght': 3}, '30s'),
#  ({'Emoticon': 0, 'Lenght': 2}, '20s'),
#  ({'Emoticon': 0, 'Lenght': 1}, '30s'),
#  ({'Emoticon': 0, 'Lenght': 2}, '40s'),
#  ({'Emoticon': 0, 'Lenght': 2}, '20s'),
#  ({'Emoticon': 0, 'Lenght': 1}, '20s'),
#  ({'Emoticon': 0, 'Lenght': 4}, '20s'),
#  ({'Emoticon': 0, 'Lenght': 3}, '20s'),
# ...

# %%
nvb_cls = nltk.NaiveBayesClassifier.train(train)

# %%
print(nltk.classify.accuracy(nvb_cls, test))
# Out:
# 0.4001252348152787

# %%
import re
import random

# %%
import nltk

# %%
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> all
# ...
#        |
#        | Downloading package abc to /root/nltk_data...
#        |   Unzipping corpora/abc.zip.
#        | Downloading package alpino to /root/nltk_data...
#        |   Unzipping corpora/alpino.zip.
#        | Downloading package biocreative_ppi to /root/nltk_data...
#        |   Unzipping corpora/biocreative_ppi.zip.
#        | Downloading package brown to /root/nltk_data...
#        |   Unzipping corpora/brown.zip.
#        | Downloading package brown_tei to /root/nltk_data...
#        |   Unzipping corpora/brown_tei.zip.
#        | Downloading package cess_cat to /root/nltk_data...
#        |   Unzipping corpora/cess_cat.zip.
# ...

# %%
from nltk.corpus import movie_reviews

# %%
documents = [(list(movie_reviews.words(fileid)), category) 
            for category in movie_reviews.categories()
            for fileid in movie_reviews.fileids(category)]

random.shuffle(documents)
documents[0]
# Out:
# (['in',
#   'my',
#   'reviews',
#   'i',
#   'try',
#   'to',
#   'make',
#   'gentle',
#   'recommendations',
#   'rather',
#   'than',
#   'telling',
#   'you',
#   'what',
#   'to',
#   'see',
#   'or',
#   'what',
#   'not',
#   'to',
#   'see',
#   '.',
#   'i',
#   'realize',
#   'that',
#   'we',
#   'all',
#   'have',
#   'different',
#   'tastes',
#   'and',
#   'i',
#   'cannot',
#   'predict',
#   'what',
#   'my',
#   'audience',
#   'will',
#   'like',
#   'and',
#   'what',
#   'they',
#   'will',
#   'dislike',
#   '.',
#   'but',
#   'in',
#   'the',
#   'case',
#   'of',
#   'american',
#   'beauty',
#   ',',
#   'i',
#   'must',
#   'make',
#   'an',
#   'exception',
#   '.',
#   'if',
#   'you',
#   'haven',
#   "'",
#   't',
#   'yet',
#   'seen',
#   'it',
#   ',',
#   'go',
#   'see',
#   'it',
#   '.',
#   'now',
#   '.',
#   'stop',
#   'reading',
#   'this',
#   'review',
#   'and',
#   'head',
#   'for',
#   'your',
#   'local',
#   'multiplex',
#   ',',
# ...

# %%
all_words = nltk.FreqDist([w.lower() for w in movie_reviews.words()])
word_features = list(all_words)[:2500]

# %%
word_features
# Out:
# ['plot',
#  ':',
#  'two',
#  'teen',
#  'couples',
#  'go',
#  'to',
#  'a',
#  'church',
#  'party',
#  ',',
#  'drink',
#  'and',
#  'then',
#  'drive',
#  '.',
#  'they',
#  'get',
#  'into',
#  'an',
#  'accident',
#  'one',
#  'of',
#  'the',
#  'guys',
#  'dies',
#  'but',
#  'his',
#  'girlfriend',
#  'continues',
#  'see',
#  'him',
#  'in',
#  'her',
#  'life',
#  'has',
#  'nightmares',
#  'what',
#  "'",
#  's',
#  'deal',
#  '?',
#  'watch',
#  'movie',
#  '"',
#  'sorta',
#  'find',
#  'out',
#  'critique',
#  'mind',
#  '-',
#  'fuck',
#  'for',
#  'generation',
#  'that',
#  'touches',
#  'on',
#  'very',
#  'cool',
#  'idea',
#  'presents',
#  'it',
#  'bad',
#  'package',
#  'which',
#  'is',
#  'makes',
#  'this',
#  'review',
#  'even',
#  'harder',
#  'write',
#  'since',
#  'i',
#  'generally',
#  'applaud',
#  'films',
#  'attempt',
#  'break',
#  'mold',
#  'mess',
#  'with',
#  'your',
#  'head',
#  'such',
#  '(',
#  'lost',
#  'highway',
#  '&',
# ...

# %%
def get_features(document):
    documnet_words = set(document)
    features = {} 

    for word in word_features:
        features[f"contains({word})"] = (word in documnet_words)
    return features

# %%
get_features(movie_reviews.words("pos/cv957_8737.txt"))
# Out:
# {'contains(plot)': True,
#  'contains(:)': True,
#  'contains(two)': True,
#  'contains(teen)': False,
#  'contains(couples)': False,
#  'contains(go)': False,
#  'contains(to)': True,
#  'contains(a)': True,
#  'contains(church)': False,
#  'contains(party)': False,
#  'contains(,)': True,
#  'contains(drink)': False,
#  'contains(and)': True,
#  'contains(then)': True,
#  'contains(drive)': False,
#  'contains(.)': True,
#  'contains(they)': True,
#  'contains(get)': True,
#  'contains(into)': True,
#  'contains(an)': True,
#  'contains(accident)': False,
#  'contains(one)': True,
#  'contains(of)': True,
#  'contains(the)': True,
#  'contains(guys)': False,
#  'contains(dies)': False,
#  'contains(but)': True,
#  'contains(his)': True,
#  'contains(girlfriend)': True,
#  'contains(continues)': False,
#  'contains(see)': False,
#  'contains(him)': True,
#  'contains(in)': True,
#  'contains(her)': False,
#  'contains(life)': False,
#  'contains(has)': True,
# ...

# %%
from sklearn.model_selection import train_test_split
features = [(get_features(d), c) for (d, c) in documents]
train, test = train_test_split(features)
cls = nltk.NaiveBayesClassifier.train(train)

# %%
print(nltk.classify.accuracy(cls, test))
# Out:
# 0.812

# %%
cls.show_most_informative_features(10)
# Out:
# Most Informative Features
#     contains(schumacher) = True              neg : pos    =      9.6 : 1.0
#        contains(martian) = True              neg : pos    =      7.6 : 1.0
#         contains(annual) = True              pos : neg    =      7.1 : 1.0
#        contains(frances) = True              pos : neg    =      7.1 : 1.0
#       contains(bothered) = True              neg : pos    =      6.9 : 1.0
#  contains(unimaginative) = True              neg : pos    =      6.9 : 1.0
#         contains(turkey) = True              neg : pos    =      6.7 : 1.0
#         contains(temper) = True              pos : neg    =      6.4 : 1.0
#          contains(waste) = True              neg : pos    =      6.4 : 1.0
#         contains(welles) = True              neg : pos    =      6.3 : 1.0

# %% [markdown]
# # Finding Info from Piles of Text

# %%
import nltk

# %%
from nltk.corpus import conll2000

# %%
chuncked_sent = conll2000.chunked_sents()[0]
print(chuncked_sent)
# Out:
# (S
#   (NP Confidence/NN)
#   (PP in/IN)
#   (NP the/DT pound/NN)
#   (VP is/VBZ widely/RB expected/VBN to/TO take/VB)
#   (NP another/DT sharp/JJ dive/NN)
#   if/IN
#   (NP trade/NN figures/NNS)
#   (PP for/IN)
#   (NP September/NNP)
#   ,/,
#   due/JJ
#   (PP for/IN)
#   (NP release/NN)
#   (NP tomorrow/NN)
#   ,/,
#   (VP fail/VB to/TO show/VB)
#   (NP a/DT substantial/JJ improvement/NN)
#   (PP from/IN)
#   (NP July/NNP and/CC August/NNP)
#   (NP 's/POS near-record/JJ deficits/NNS)
#   ./.)

# %%
from nltk.chunk import tree2conlltags, conlltags2tree

# %%
iob_tagged = tree2conlltags(chuncked_sent)
print(iob_tagged)
# Out:
# [('Confidence', 'NN', 'B-NP'), ('in', 'IN', 'B-PP'), ('the', 'DT', 'B-NP'), ('pound', 'NN', 'I-NP'), ('is', 'VBZ', 'B-VP'), ('widely', 'RB', 'I-VP'), ('expected', 'VBN', 'I-VP'), ('to', 'TO', 'I-VP'), ('take', 'VB', 'I-VP'), ('another', 'DT', 'B-NP'), ('sharp', 'JJ', 'I-NP'), ('dive', 'NN', 'I-NP'), ('if', 'IN', 'O'), ('trade', 'NN', 'B-NP'), ('figures', 'NNS', 'I-NP'), ('for', 'IN', 'B-PP'), ('September', 'NNP', 'B-NP'), (',', ',', 'O'), ('due', 'JJ', 'O'), ('for', 'IN', 'B-PP'), ('release', 'NN', 'B-NP'), ('tomorrow', 'NN', 'B-NP'), (',', ',', 'O'), ('fail', 'VB', 'B-VP'), ('to', 'TO', 'I-VP'), ('show', 'VB', 'I-VP'), ('a', 'DT', 'B-NP'), ('substantial', 'JJ', 'I-NP'), ('improvement', 'NN', 'I-NP'), ('from', 'IN', 'B-PP'), ('July', 'NNP', 'B-NP'), ('and', 'CC', 'I-NP'), ('August', 'NNP', 'I-NP'), ("'s", 'POS', 'B-NP'), ('near-record', 'JJ', 'I-NP'), ('deficits', 'NNS', 'I-NP'), ('.', '.', 'O')]

# %%
print(len(conll2000.chunked_words()))
print(len(conll2000.chunked_sents()))
# Out:
# 166433
# 10948

# %%
import random

# %%
from sklearn.model_selection import train_test_split

# %%
shuffled_conll_sents = list(conll2000.chunked_sents())
train, test = train_test_split(shuffled_conll_sents, test_size=0.1)

# %%
from nltk import ChunkParserI, TrigramTagger

# %%
class TrigramChunkerParser(ChunkParserI):
    def __init__(self, train):
        train = [[(pos_tag, chunk_tag) for word, pos_tag, chunk_tag in tree2conlltags(sent)] for sent in train]
