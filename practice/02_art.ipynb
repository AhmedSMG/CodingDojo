# %%
from datetime import datetime
import numpy as np
import pandas as pd
import pandas_datareader as pdr
import plotly.express as px
import plotly.graph_objects as go

# %%
# Volatility == Risk
# ATR => Average True Range
# TR = max[H - L, |H - C_p|, |L - C_p|]
# ATR = 1 / n sum(TR_i)
# TR_i -> a particluar true ranger
# n -> The time period employed
# H -> Current High
# L -> Current Low
# C_p -> previous Close

# %%
stocks = pdr.get_data_yahoo("NFLX", "2020-01-01")
stocks
# Out:
#                   High         Low        Open       Close   Volume  \
# Date
# 2020-01-02  329.980011  324.779999  326.100006  329.809998  4485800
# 2020-01-03  329.859985  325.529999  326.779999  325.899994  3806900
# 2020-01-06  336.359985  321.200012  323.119995  335.829987  5663100
# 2020-01-07  336.700012  330.299988  336.470001  330.750000  4703200
# 2020-01-08  342.700012  331.049988  331.489990  339.260010  7104500
# ...                ...         ...         ...         ...      ...
# 2021-10-21  654.010010  628.650024  628.890015  653.159973  8437100
# 2021-10-22  665.460022  651.809998  651.809998  664.780029  6179700
# 2021-10-25  675.880005  657.070007  663.739990  671.659973  3833500
# 2021-10-26  676.489990  662.770020  673.760010  668.520020  2904800
# 2021-10-27  671.409973  661.849976  669.000000  662.919983  2274600
#
#              Adj Close
# Date
# 2020-01-02  329.809998
# 2020-01-03  325.899994
# 2020-01-06  335.829987
# 2020-01-07  330.750000
# 2020-01-08  339.260010
# ...                ...
# 2021-10-21  653.159973
# 2021-10-22  664.780029
# 2021-10-25  671.659973
# 2021-10-26  668.520020
# 2021-10-27  662.919983
#
# [460 rows x 6 columns]

# %%
params = pd.DataFrame(data={
    "High Low": stocks.High - stocks.Low,
    "High Close Pervious": np.abs(stocks.High - stocks.Close.shift()),
    "Low Close Pervious": np.abs(stocks.High - stocks.Close.shift())
})
params
# Out:
#              High Low  High Close Pervious  Low Close Pervious
# Date
# 2020-01-02   5.200012                  NaN                 NaN
# 2020-01-03   4.329987             0.049988            0.049988
# 2020-01-06  15.159973            10.459991           10.459991
# 2020-01-07   6.400024             0.870026            0.870026
# 2020-01-08  11.650024            11.950012           11.950012
# ...               ...                  ...                 ...
# 2021-10-21  25.359985            28.869995           28.869995
# 2021-10-22  13.650024            12.300049           12.300049
# 2021-10-25  18.809998            11.099976           11.099976
# 2021-10-26  13.719971             4.830017            4.830017
# 2021-10-27   9.559998             2.889954            2.889954
#
# [460 rows x 3 columns]

# %%
true_range = np.max(params, axis=1)
true_range
# Out:
# Date
# 2020-01-02     5.200012
# 2020-01-03     4.329987
# 2020-01-06    15.159973
# 2020-01-07     6.400024
# 2020-01-08    11.950012
#                 ...
# 2021-10-21    28.869995
# 2021-10-22    13.650024
# 2021-10-25    18.809998
# 2021-10-26    13.719971
# 2021-10-27     9.559998
# Length: 460, dtype: float64

# %%
average_true_range = true_range.rolling(14).mean()

# %%
fig = go.Figure(layout=dict(title="Price & ATR",
                            height=800,
                            yaxis=dict(title="Price"),
                            yaxis2=dict(title="ATR",
                                        overlaying="y",
                                        side="right")))

fig.add_trace(go.Scatter(x=average_true_range.index,
                         y=average_true_range,
                         name="ATR",
                         yaxis="y1"))

fig.add_trace(go.Scatter(x=stocks.index,
                         y=stocks.Close,
                         name="Close Price",
                         yaxis="y2"))

fig.show()
# Out:
# <div>                            <div id="8cf04445-f03f-47c3-8732-8bb7016bef23" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8cf04445-f03f-47c3-8732-8bb7016bef23")) {                    Plotly.newPlot(                        "8cf04445-f03f-47c3-8732-8bb7016bef23",                        [{"name":"ATR","type":"scatter","x":["2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-13T00:00:00","2020-01-14T00:00:00","2020-01-15T00:00:00","2020-01-16T00:00:00","2020-01-17T00:00:00","2020-01-21T00:00:00","2020-01-22T00:00:00","2020-01-23T00:00:00","2020-01-24T00:00:00","2020-01-27T00:00:00","2020-01-28T00:00:00","2020-01-29T00:00:00","2020-01-30T00:00:00","2020-01-31T00:00:00","2020-02-03T00:00:00","2020-02-04T00:00:00","2020-02-05T00:00:00","2020-02-06T00:00:00","2020-02-07T00:00:00","2020-02-10T00:00:00","2020-02-11T00:00:00","2020-02-12T00:00:00","2020-02-13T00:00:00","2020-02-14T00:00:00","2020-02-18T00:00:00","2020-02-19T00:00:00","2020-02-20T00:00:00","2020-02-21T00:00:00","2020-02-24T00:00:00","2020-02-25T00:00:00","2020-02-26T00:00:00","2020-02-27T00:00:00","2020-02-28T00:00:00","2020-03-02T00:00:00","2020-03-03T00:00:00","2020-03-04T00:00:00","2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-09T00:00:00","2020-03-10T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-02T00:00:00","2020-04-03T00:00:00","2020-04-06T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-13T00:00:00","2020-04-14T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-20T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-01T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-05-08T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-03T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-08T00:00:00","2020-06-09T00:00:00","2020-06-10T00:00:00","2020-06-11T00:00:00","2020-06-12T00:00:00","2020-06-15T00:00:00","2020-06-16T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-19T00:00:00","2020-06-22T00:00:00","2020-06-23T00:00:00","2020-06-24T00:00:00","2020-06-25T00:00:00","2020-06-26T00:00:00","2020-06-29T00:00:00","2020-06-30T00:00:00","2020-07-01T00:00:00","2020-07-02T00:00:00","2020-07-06T00:00:00","2020-07-07T00:00:00","2020-07-08T00:00:00","2020-07-09T00:00:00","2020-07-10T00:00:00","2020-07-13T00:00:00","2020-07-14T00:00:00","2020-07-15T00:00:00","2020-07-16T00:00:00","2020-07-17T00:00:00","2020-07-20T00:00:00","2020-07-21T00:00:00","2020-07-22T00:00:00","2020-07-23T00:00:00","2020-07-24T00:00:00","2020-07-27T00:00:00","2020-07-28T00:00:00","2020-07-29T00:00:00","2020-07-30T00:00:00","2020-07-31T00:00:00","2020-08-03T00:00:00","2020-08-04T00:00:00","2020-08-05T00:00:00","2020-08-06T00:00:00","2020-08-07T00:00:00","2020-08-10T00:00:00","2020-08-11T00:00:00","2020-08-12T00:00:00","2020-08-13T00:00:00"," ...
