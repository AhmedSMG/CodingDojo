# %% [markdown]
# #### Week 2, Assignment C1:
# ### Exploring some Crowdfunding Data with Pandas
#
# In this notebook we will aim to explore a few key activities using Pandas
#
# Please complete the lines bellow where you see "# TODO"

# %%
# Objective 1.
#Use this cell to import your packages
import numpy as np
import pandas as pd

# %%
pd.options.display.max_columns = None

# %%
# Objective 2.
# Complete the following cell using pandas.read_csv() 
# and the file included in this assignment.
# Tip: set index_col to 'created_at' and parse_dates=True

df = pd.read_csv("kickstarter_sample.csv", parse_dates=["created_at"])

assert len(df)>0
# if you get an error, try again

# %%
# Objective 3.
# Use this cell to examine the data you've loaded, specifically note the headers and index
df
# Out:
#                created_at  backers_count  \
# 0     2009-04-25 05:37:50             25
# 1     2009-08-25 18:21:02             36
# 2     2009-08-30 16:57:43             82
# 3     2009-09-14 23:58:49             10
# 4     2009-10-11 20:28:44            156
# ...                   ...            ...
# 10976 2021-05-08 19:57:26              4
# 10977 2021-05-08 19:57:26              4
# 10978 2021-05-09 04:06:34             18
# 10979 2021-05-09 14:32:09              1
# 10980 2021-05-10 02:24:04              2
#
#                                                    blurb  \
# 0      This is a project to create a free iPhone app ...
# 1      Your donation will go directly to the purchase...
# 2      Exploring a classic style of portraiture and f...
# 3      World renowned artist collective, Bandwagon, s...
# 4      Six series of 100 signed and numbered tabletop...
# ...                                                  ...
# 10976         "Once Upon a Time in...Hollywood"- Parody.
# 10977         "Once Upon a Time in...Hollywood"- Parody.
# 10978  NEW Variant Covers for War Angels Issues 4 and 5!
# 10979             Taylor Swift Every Era Soft Enamel Pin
# 10980  Tale of Xestuoria is a fantasy podcast, full o...
#
#                                                 category  \
# 0      {"id":51,"name":"Software","analytics_name":"S...
# 1      {"id":23,"name":"Painting","analytics_name":"P...
# 2      {"id":23,"name":"Painting","analytics_name":"P...
# 3      {"id":23,"name":"Painting","analytics_name":"P...
# 4      {"id":25,"name":"Sculpture","analytics_name":"...
# ...                                                  ...
# 10976  {"id":292,"name":"Comedy","analytics_name":"Co...
# 10977  {"id":292,"name":"Comedy","analytics_name":"Co...
# 10978  {"id":250,"name":"Comic Books","analytics_name...
# 10979  {"id":1,"name":"Art","analytics_name":"Art","s...
# 10980  {"id":239,"name":"Radio & Podcasts","analytics...
#
#        converted_pledged_amount country country_displayable_name  \
# 0                           145      US        the United States
# 1                          2562      US        the United States
# 2                          3800      US        the United States
# 3                           830      US        the United States
# 4                         10021      US        the United States
# ...                         ...     ...                      ...
# 10976                       114      US        the United States
# 10977                       114      US        the United States
# 10978                       928      US        the United States
# 10979                         1      GB       the United Kingdom
# 10980                         4      GB       the United Kingdom
#
#                                                  creator currency  \
# 0      {"id":473191023,"name":"Dan Phiffer","slug":"d...      USD
# 1      {"id":2042273139,"name":"miya ando","is_regist...      USD
# 2      {"id":1671016343,"name":"Matt Held","is_regist...      USD
# 3      {"id":699171192,"name":"Chad Stayrook","slug":...      USD
# 4      {"id":1371762709,"name":"John T. Unger","slug"...      USD
# ...                                                  ...      ...
# 10976  {"id":341623704,"name":"Mark Mos","slug":"mark...      USD
# 10977  {"id":341623704,"name":"Mark Mos","slug":"mark...      USD
# 10978  {"id":997307575,"name":"Mountaineer West Produ...      USD
# 10979  {"id":579144618,"name":"Abbie","slug":"cruelre...      GBP
# 10980  {"id":296352873,"name":"Rhys Smart","slug":"rh...      GBP
#
#       currency_symbol  currency_trailing_code current_currency    deadline  \
# 0                   $                    True              USD  1247554799
# 1                   $                    True              USD  1256731200
# 2                   $                    True              USD  1255622400
# 3                   $                    True              USD  1261303140
# 4                   $                    True              USD  1257656340
# ...               ...                     ...              ...         ...
# 10976               $                    True              USD  1623101052
# 10977               $                    True              USD  1623101052
# 10978               $                    True              USD  1621395000
# 10979               £                   False              USD  1625972106
# 10980               £                   False              USD  1623208220
#
#        disable_communication friends   fx_rate     goal          id  \
# 0                      False     NaN  1.000000     99.0      727286
# 1                      False     NaN  1.000000   2000.0   333862461
# 2                      False     NaN  1.000000   3500.0  1686482513
# 3                      False     NaN  1.000000    700.0  1638167658
# 4                      False     NaN  1.000000   5000.0  1779648507
# ...                      ...     ...       ...      ...         ...
# 10976                  False     NaN  1.000000   1000.0   179177476
# 10977                  False     NaN  1.000000   1000.0   179177476
# 10978                  False     NaN  1.000000    300.0   433104325
# 10979                  False     NaN  1.406145    250.0  1162912597
# 10980                  False     NaN  1.406145  15000.0  1785156251
#
#       is_backing  is_starrable is_starred  launched_at  \
# 0            NaN         False        NaN   1240673781
# 1            NaN         False        NaN   1251732800
# 2            NaN         False        NaN   1252879941
# 3            NaN         False        NaN   1253576261
# 4            NaN         False        NaN   1255370621
# ...          ...           ...        ...          ...
# 10976        NaN          True        NaN   1620509052
# 10977        NaN          True        NaN   1620509052
# 10978        NaN          True        NaN   1620779910
# 10979        NaN          True        NaN   1620788106
# 10980        NaN          True        NaN   1620616220
#
#                                                 location  \
# 0                                                    NaN
# 1      {"id":1580913,"name":"Durban","slug":"durban-z...
# 2      {"id":2459115,"name":"New York","slug":"new-yo...
# 3      {"id":729028,"name":"Eindhoven","slug":"eindho...
# 4      {"id":2444638,"name":"Mancelona","slug":"mance...
# ...                                                  ...
# 10976  {"id":2442047,"name":"Los Angeles","slug":"los...
# 10977  {"id":2442047,"name":"Los Angeles","slug":"los...
# 10978  {"id":2476016,"name":"Poulsbo","slug":"poulsbo...
# 10979  {"id":21125,"name":"Glasgow","slug":"glasgow-g...
# 10980  {"id":18581,"name":"Dudley","slug":"dudley-dud...
#
#                                                     name permissions  \
# 0                           Offline Wikipedia iPhone app         NaN
# 1      Art Supplies, Books & Education for Indigo You...         NaN
# 2                Matt Held - Phase II Facebook paintings         NaN
# 3      Bandwagon artist collaboration seeks exhibitio...         NaN
# 4                Fire Imp Sculptures: Series 1 through 6         NaN
# ...                                                  ...         ...
# 10976         "Once Upon a Time in...Hollywood"- Parody.         NaN
# 10977         "Once Upon a Time in...Hollywood"- Parody.         NaN
# 10978                          War Angels Variant Covers         NaN
# 10979                         Taylor Swift Every Era Pin         NaN
# 10980                  Tale of Xestuoria fantasy podcast         NaN
#
#                                                    photo  pledged  \
# 0      {"key":"assets/011/257/342/9cdd50f7e209fd834ce...    145.0
# 1      {"key":"assets/011/257/825/4461f9c070c6fb2d91c...   2562.0
# 2      {"key":"assets/011/257/877/624643f63ac47f4e43c...   3800.0
# 3      {"key":"assets/011/258/168/49246a7beb841017f80...    830.0
# 4      {"key":"assets/011/258/406/ce79e5c9f92859fae1d...  10021.0
# ...                                                  ...      ...
# 10976  {"key":"assets/033/442/049/c8d542f517791780c05...    114.0
# 10977  {"key":"assets/033/442/049/c8d542f517791780c05...    114.0
# 10978  {"key":"assets/033/445/266/12e4da382f21bbfe4eb...    928.0
# 10979  {"key":"assets/033/448/626/4dff96b76305c61ea0c...      1.0
# 10980  {"key":"assets/033/461/518/ae58766ab9a5b20438b...      3.0
#
#                                                  profile  \
# 0      {"id":70,"project_id":70,"state":"inactive","s...
# 1      {"id":663,"project_id":663,"state":"inactive",...
# 2      {"id":724,"project_id":724,"state":"inactive",...
# 3      {"id":1144,"project_id":1144,"state":"inactive...
# 4      {"id":1445,"project_id":1445,"state":"inactive...
# ...                                                  ...
# 10976  {"id":4213381,"project_id":4213381,"state":"in...
# 10977  {"id":4213381,"project_id":4213381,"state":"in...
# 10978  {"id":4213555,"project_id":4213555,"state":"in...
# 10979  {"id":4213709,"project_id":4213709,"state":"in...
# 10980  {"id":4213956,"project_id":4213956,"state":"in...
#
#                                                     slug  \
# 0                           offline-wikipedia-iphone-app
# 1      art-supplies-books-and-education-for-indigo-yo...
# 2                  matt-held-facebook-portraits-phase-ii
# 3      bandwagon-artist-collaboration-seeks-exhibitio...
# 4                 fire-imp-sculptures-series-1-through-6
# ...                                                  ...
# 10976                once-upon-a-time-inhollywood-parody
# 10977                once-upon-a-time-inhollywood-parody
# 10978                          war-angels-variant-covers
# 10979                         taylor-swift-every-era-pin
# 10980                  tale-of-xestuoria-fantasy-podcast
#
#                                               source_url  spotlight  \
# 0      https://www.kickstarter.com/discover/categorie...       True
# 1      https://www.kickstarter.com/discover/categorie...       True
# 2      https://www.kickstarter.com/discover/categorie...       True
# 3      https://www.kickstarter.com/discover/categorie...       True
# 4      https://www.kickstarter.com/discover/categorie...       True
# ...                                                  ...        ...
# 10976  https://www.kickstarter.com/discover/categorie...      False
# 10977  https://www.kickstarter.com/discover/categorie...      False
# 10978  https://www.kickstarter.com/discover/categorie...      False
# 10979  https://www.kickstarter.com/discover/categorie...      False
# 10980  https://www.kickstarter.com/discover/categorie...      False
#
#        staff_pick       state  state_changed_at  static_usd_rate  \
# 0            True  successful        1247554830         1.000000
# 1           False  successful        1256731209         1.000000
# 2            True  successful        1255622410         1.000000
# 3           False  successful        1261303209         1.000000
# 4            True  successful        1257656410         1.000000
# ...           ...         ...               ...              ...
# 10976       False        live        1620509053         1.000000
# 10977       False        live        1620509053         1.000000
# 10978       False        live        1620779912         1.000000
# 10979       False        live        1620788107         1.412044
# 10980       False        live        1620616221         1.398500
#
#                                                     urls  usd_exchange_rate  \
# 0      {"web":{"project":"https://www.kickstarter.com...           1.000000
# 1      {"web":{"project":"https://www.kickstarter.com...           1.000000
# 2      {"web":{"project":"https://www.kickstarter.com...           1.000000
# 3      {"web":{"project":"https://www.kickstarter.com...           1.000000
# 4      {"web":{"project":"https://www.kickstarter.com...           1.000000
# ...                                                  ...                ...
# 10976  {"web":{"project":"https://www.kickstarter.com...           1.000000
# 10977  {"web":{"project":"https://www.kickstarter.com...           1.000000
# 10978  {"web":{"project":"https://www.kickstarter.com...           1.000000
# 10979  {"web":{"project":"https://www.kickstarter.com...           1.406145
# 10980  {"web":{"project":"https://www.kickstarter.com...           1.406145
#
#         usd_pledged       usd_type
# 0        145.000000  international
# 1       2562.000000  international
# 2       3800.000000  international
# 3        830.000000  international
# 4      10021.000000  international
# ...             ...            ...
# 10976    114.000000  international
# 10977    114.000000  international
# 10978    928.000000  international
# 10979      1.412044  international
# 10980      4.195499  international
#
# [10981 rows x 39 columns]

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10981 entries, 0 to 10980
# Data columns (total 39 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   created_at                10981 non-null  datetime64[ns]
#  1   backers_count             10981 non-null  int64
#  2   blurb                     10979 non-null  object
#  3   category                  10981 non-null  object
#  4   converted_pledged_amount  10981 non-null  int64
#  5   country                   10981 non-null  object
#  6   country_displayable_name  10981 non-null  object
#  7   creator                   10981 non-null  object
#  8   currency                  10981 non-null  object
#  9   currency_symbol           10981 non-null  object
#  10  currency_trailing_code    10981 non-null  bool
#  11  current_currency          10981 non-null  object
#  12  deadline                  10981 non-null  int64
#  13  disable_communication     10981 non-null  bool
#  14  friends                   2 non-null      object
#  15  fx_rate                   10981 non-null  float64
#  16  goal                      10981 non-null  float64
#  17  id                        10981 non-null  int64
#  18  is_backing                2 non-null      object
#  19  is_starrable              10981 non-null  bool
#  20  is_starred                2 non-null      object
#  21  launched_at               10981 non-null  int64
#  22  location                  10975 non-null  object
#  23  name                      10981 non-null  object
#  24  permissions               2 non-null      object
#  25  photo                     10981 non-null  object
#  26  pledged                   10981 non-null  float64
#  27  profile                   10981 non-null  object
#  28  slug                      10981 non-null  object
#  29  source_url                10981 non-null  object
#  30  spotlight                 10981 non-null  bool
#  31  staff_pick                10981 non-null  bool
#  32  state                     10981 non-null  object
#  33  state_changed_at          10981 non-null  int64
#  34  static_usd_rate           10981 non-null  float64
#  35  urls                      10981 non-null  object
#  36  usd_exchange_rate         10981 non-null  float64
#  37  usd_pledged               10981 non-null  float64
#  38  usd_type                  10980 non-null  object
# dtypes: bool(5), datetime64[ns](1), float64(6), int64(6), object(21)
# memory usage: 2.9+ MB

# %%
# Objective 4.
# Create a slice from the years 2018 to 2021

df = df.query(" 2018 <= created_at.dt.year < 2021")
df
# Out:
#                created_at  backers_count  \
# 6091  2018-01-01 00:37:02             15
# 6092  2018-01-02 12:04:32             13
# 6093  2018-01-02 21:51:43            331
# 6094  2018-01-02 22:04:22            124
# 6095  2018-01-02 23:45:25            105
# ...                   ...            ...
# 10286 2020-12-30 22:09:04            495
# 10287 2020-12-31 01:41:40            353
# 10288 2020-12-31 09:41:45            718
# 10289 2020-12-31 15:08:36             34
# 10290 2020-12-31 21:02:54             77
#
#                                                    blurb  \
# 6091   Oy With The plushies Already makes crochet/ kn...
# 6092   Castle Elysium is the Sanctuary for two twin S...
# 6093   From Zero to Full-Stack Engineer. Build Web Ap...
# 6094   Bringing the love of comics back to a new gene...
# 6095         64 pages of adventures in the 18th Century!
# ...                                                  ...
# 10286  An autobiographical comic that explores the in...
# 10287  Outstanding in every way, from design to finis...
# 10288  If you like Pixar animation, you'll love this!...
# 10289  Design watch coming in the packaging you can u...
# 10290      Charming lil magical buggy enamel pin series!
#
#                                                 category  \
# 6091   {"id":344,"name":"Crochet","analytics_name":"C...
# 6092   {"id":253,"name":"Webcomics","analytics_name":...
# 6093   {"id":342,"name":"Web","analytics_name":"Web",...
# 6094   {"id":46,"name":"Children's Books","analytics_...
# 6095   {"id":249,"name":"Anthologies","analytics_name...
# ...                                                  ...
# 10286  {"id":250,"name":"Comic Books","analytics_name...
# 10287  {"id":7,"name":"Design","analytics_name":"Desi...
# 10288  {"id":29,"name":"Animation","analytics_name":"...
# 10289  {"id":28,"name":"Product Design","analytics_na...
# 10290  {"id":28,"name":"Product Design","analytics_na...
#
#        converted_pledged_amount country country_displayable_name  \
# 6091                        626      US        the United States
# 6092                        233      US        the United States
# 6093                      21349      AU                Australia
# 6094                       4963      NZ              New Zealand
# 6095                       2936      GB       the United Kingdom
# ...                         ...     ...                      ...
# 10286                     11872      US        the United States
# 10287                    179176      AU                Australia
# 10288                     26876      ES                    Spain
# 10289                      4124      DE                  Germany
# 10290                      2259      US        the United States
#
#                                                  creator currency  \
# 6091   {"id":1039559704,"name":"Shelina Fitzpatrick",...      USD
# 6092   {"id":464124037,"name":"Mauricio Valdivia","sl...      USD
# 6093   {"id":985537798,"name":"Zenva","slug":"pablofa...      AUD
# 6094   {"id":404115547,"name":"ME : Publishing Made E...      NZD
# 6095   {"id":1815843378,"name":"Steve Tanner","slug":...      GBP
# ...                                                  ...      ...
# 10286  {"id":282227561,"name":"Jamila Rowser","slug":...      USD
# 10287  {"id":224529554,"name":"Peter Sargison","slug"...      AUD
# 10288  {"id":334881362,"name":"Nacho Diaz","slug":"na...      EUR
# 10289  {"id":1142335979,"name":"Widdenburg watch","sl...      EUR
# 10290  {"id":2064044544,"name":"Ash","slug":"fleacirc...      USD
#
#       currency_symbol  currency_trailing_code current_currency    deadline  \
# 6091                $                    True              USD  1517198400
# 6092                $                    True              USD  1516082400
# 6093                $                    True              USD  1518181200
# 6094                $                    True              USD  1518552101
# 6095                £                   False              USD  1519938000
# ...               ...                     ...              ...         ...
# 10286               $                    True              USD  1615953540
# 10287               $                    True              USD  1617798593
# 10288               €                   False              USD  1613571729
# 10289               €                   False              USD  1615872020
# 10290               $                    True              USD  1618174824
#
#        disable_communication friends   fx_rate     goal          id  \
# 6091                   False     NaN  1.000000    395.0  1506969831
# 6092                   False     NaN  1.000000    220.0   877409669
# 6093                   False     NaN  0.778677    500.0  1114123054
# 6094                   False     NaN  0.716905   5000.0  2132569456
# 6095                   False     NaN  1.406145    500.0  2061869910
# ...                      ...     ...       ...      ...         ...
# 10286                  False     NaN  1.000000   3200.0   722477969
# 10287                  False     NaN  0.772229  72000.0   438033315
# 10288                  False     NaN  1.207659  15000.0  1348884127
# 10289                  False     NaN  1.207659   2000.0   302299607
# 10290                  False     NaN  1.000000   2000.0    50303995
#
#       is_backing  is_starrable is_starred  launched_at  \
# 6091         NaN         False        NaN   1515015128
# 6092         NaN         False        NaN   1515195027
# 6093         NaN         False        NaN   1515597268
# 6094         NaN         False        NaN   1515960101
# 6095         NaN         False        NaN   1516865820
# ...          ...           ...        ...          ...
# 10286        NaN         False        NaN   1613478681
# 10287        NaN         False        NaN   1616070593
# 10288        NaN         False        NaN   1610979729
# 10289        NaN         False        NaN   1612419620
# 10290        NaN         False        NaN   1615586424
#
#                                                 location  \
# 6091   {"id":2400849,"name":"Everett","slug":"everett...
# 6092   {"id":2407517,"name":"Fresno","slug":"fresno-c...
# 6093   {"id":1100661,"name":"Brisbane","slug":"brisba...
# 6094   {"id":2348079,"name":"Auckland","slug":"auckla...
# 6095   {"id":12723,"name":"Birmingham","slug":"birmin...
# ...                                                  ...
# 10286  {"id":2450022,"name":"Miami","slug":"miami-fl"...
# 10287  {"id":1103816,"name":"Melbourne","slug":"melbo...
# 10288  {"id":766356,"name":"Malaga","slug":"malaga-ma...
# 10289  {"id":676757,"name":"Munich","slug":"munich-de...
# 10290  {"id":2470512,"name":"Pepperell","slug":"peppe...
#
#                                                     name permissions  \
# 6091                                    Comicon or Bust!         NaN
# 6092         Gemini Twilight - Issue #1 (Webcomic Pages)         NaN
# 6093              Full-Stack Web Development Mini-Degree         NaN
# 6094   The Adventures of Jack Scratch - Reclaiming co...         NaN
# 6095                                Flintlock Book Three         NaN
# ...                                                  ...         ...
# 10286            The Saddest Angriest Black Girl in Town         NaN
# 10287  The Mandala: an automatic sport / dress watch ...         NaN
# 10288       HOMEWORK - 3d animated short-film by Naolito         NaN
# 10289            Design watch + packaging you can re-use         NaN
# 10290                      Micro Magic Enamel Pin Series         NaN
#
#                                                    photo    pledged  \
# 6091   {"key":"assets/019/734/504/e51c8f6c5f21a0a88af...     626.00
# 6092   {"key":"assets/019/743/730/c8422d4b7731088612f...     233.00
# 6093   {"key":"assets/019/748/417/e7befb2d808cebf713b...   27441.00
# 6094   {"key":"assets/019/748/571/e35461deb3d4ed3c1fd...    6831.00
# 6095   {"key":"assets/019/802/903/c80fdc3cee24d93c7ae...    2136.00
# ...                                                  ...        ...
# 10286  {"key":"assets/032/382/734/f0c9fdc1e2855d729e8...   11872.00
# 10287  {"key":"assets/032/878/420/06ecb50146b5db81ea1...  234136.32
# 10288  {"key":"assets/032/379/551/a3589b2d913d98de880...   22226.50
# 10289  {"key":"assets/031/882/568/f653fcf8e6e3f80211d...    3456.00
# 10290  {"key":"assets/032/339/827/9b8893784423078eb84...    2259.00
#
#                                                  profile  \
# 6091   {"id":3262740,"project_id":3262740,"state":"in...
# 6092   {"id":3263814,"project_id":3263814,"state":"ac...
# 6093   {"id":3264345,"project_id":3264345,"state":"ac...
# 6094   {"id":3264358,"project_id":3264358,"state":"ac...
# 6095   {"id":3264468,"project_id":3264468,"state":"in...
# ...                                                  ...
# 10286  {"id":4134561,"project_id":4134561,"state":"ac...
# 10287  {"id":4134661,"project_id":4134661,"state":"ac...
# 10288  {"id":4134800,"project_id":4134800,"state":"ac...
# 10289  {"id":4134884,"project_id":4134884,"state":"ac...
# 10290  {"id":4134992,"project_id":4134992,"state":"ac...
#
#                                                     slug  \
# 6091    send-oy-plushies-to-comicon-artist-alley-in-2018
# 6092              gemini-twilight-issue-1-webcomic-pages
# 6093              full-stack-web-development-mini-degree
# 6094   the-adventures-of-jack-scratch-reclaiming-comi...
# 6095                                flintlock-book-three
# ...                                                  ...
# 10286            the-saddest-angriest-black-girl-in-town
# 10287                                        the-mandala
# 10288         homework-3d-animated-short-film-by-naolito
# 10289              design-watch-packaging-you-can-re-use
# 10290                                        micro-magic
#
#                                               source_url  spotlight  \
# 6091   https://www.kickstarter.com/discover/categorie...       True
# 6092   https://www.kickstarter.com/discover/categorie...       True
# 6093   https://www.kickstarter.com/discover/categorie...       True
# 6094   https://www.kickstarter.com/discover/categorie...       True
# 6095   https://www.kickstarter.com/discover/categorie...       True
# ...                                                  ...        ...
# 10286  https://www.kickstarter.com/discover/categorie...       True
# 10287  https://www.kickstarter.com/discover/categorie...       True
# 10288  https://www.kickstarter.com/discover/categorie...       True
# 10289  https://www.kickstarter.com/discover/categorie...       True
# 10290  https://www.kickstarter.com/discover/categorie...       True
#
#        staff_pick       state  state_changed_at  static_usd_rate  \
# 6091        False  successful        1517198400         1.000000
# 6092        False  successful        1516082400         1.000000
# 6093        False  successful        1518181202         0.785310
# 6094        False  successful        1518552101         0.725750
# 6095        False  successful        1519938001         1.403011
# ...           ...         ...               ...              ...
# 10286        True  successful        1615953541         1.000000
# 10287       False  successful        1617798593         0.773445
# 10288        True  successful        1613571729         1.207950
# 10289       False  successful        1615872020         1.204346
# 10290       False  successful        1618174825         1.000000
#
#                                                     urls  usd_exchange_rate  \
# 6091   {"web":{"project":"https://www.kickstarter.com...           1.000000
# 6092   {"web":{"project":"https://www.kickstarter.com...           1.000000
# 6093   {"web":{"project":"https://www.kickstarter.com...           0.778008
# 6094   {"web":{"project":"https://www.kickstarter.com...           0.726680
# 6095   {"web":{"project":"https://www.kickstarter.com...           1.374982
# ...                                                  ...                ...
# 10286  {"web":{"project":"https://www.kickstarter.com...           1.000000
# 10287  {"web":{"project":"https://www.kickstarter.com...           0.765264
# 10288  {"web":{"project":"https://www.kickstarter.com...           1.209219
# 10289  {"web":{"project":"https://www.kickstarter.com...           1.193383
# 10290  {"web":{"project":"https://www.kickstarter.com...           1.000000
#
#          usd_pledged       usd_type
# 6091      626.000000  international
# 6092      233.000000  international
# 6093    21549.699942  international
# 6094     4957.598045  international
# 6095     2996.830599  international
# ...              ...            ...
# 10286   11872.000000  international
# 10287  181091.530902  international
# 10288   26848.495341  international
# 10289    4162.220605  international
# 10290    2259.000000  international
#
# [4200 rows x 39 columns]

# %%
# Objective 5.
# slice into the following collumns
# 'backers_count','blurb','country','usd_pledged','state'

df = df.loc[:, ['backers_count','blurb','country','usd_pledged','state']]
df
# Out:
#        backers_count                                              blurb  \
# 6091              15  Oy With The plushies Already makes crochet/ kn...
# 6092              13  Castle Elysium is the Sanctuary for two twin S...
# 6093             331  From Zero to Full-Stack Engineer. Build Web Ap...
# 6094             124  Bringing the love of comics back to a new gene...
# 6095             105        64 pages of adventures in the 18th Century!
# ...              ...                                                ...
# 10286            495  An autobiographical comic that explores the in...
# 10287            353  Outstanding in every way, from design to finis...
# 10288            718  If you like Pixar animation, you'll love this!...
# 10289             34  Design watch coming in the packaging you can u...
# 10290             77      Charming lil magical buggy enamel pin series!
#
#       country    usd_pledged       state
# 6091       US     626.000000  successful
# 6092       US     233.000000  successful
# 6093       AU   21549.699942  successful
# 6094       NZ    4957.598045  successful
# 6095       GB    2996.830599  successful
# ...       ...            ...         ...
# 10286      US   11872.000000  successful
# 10287      AU  181091.530902  successful
# 10288      ES   26848.495341  successful
# 10289      DE    4162.220605  successful
# 10290      US    2259.000000  successful
#
# [4200 rows x 5 columns]

# %%
# Objective 6.
# Use integer-location based indexing to exclude the last 3 row of data

df = df.iloc[:-3]
df
# Out:
#        backers_count                                              blurb  \
# 6091              15  Oy With The plushies Already makes crochet/ kn...
# 6092              13  Castle Elysium is the Sanctuary for two twin S...
# 6093             331  From Zero to Full-Stack Engineer. Build Web Ap...
# 6094             124  Bringing the love of comics back to a new gene...
# 6095             105        64 pages of adventures in the 18th Century!
# ...              ...                                                ...
# 10283             28                          Hard enamel monster pins.
# 10284              2  A brand new convention for every cosplayer, ar...
# 10285            120  A kick ass motivational enamel pin featuring t...
# 10286            495  An autobiographical comic that explores the in...
# 10287            353  Outstanding in every way, from design to finis...
#
#       country    usd_pledged       state
# 6091       US     626.000000  successful
# 6092       US     233.000000  successful
# 6093       AU   21549.699942  successful
# 6094       NZ    4957.598045  successful
# 6095       GB    2996.830599  successful
# ...       ...            ...         ...
# 10283      GB     713.741584  successful
# 10284      US       2.000000      failed
# 10285      GB    2774.202113  successful
# 10286      US   11872.000000  successful
# 10287      AU  181091.530902  successful
#
# [4197 rows x 5 columns]

# %%
# Objective 7.
# Inside of your slice, count the total number of backers

total_backers = df["backers_count"].sum()
total_backers
# Out:
# 819406

# %%
df["state"].value_counts()
# Out:
# successful    3025
# failed        1001
# canceled       139
# live            32
# Name: state, dtype: int64

# %%
# Objective 8.
# Use a mask to split the DataFrame into two parts and assign each to a variable.
# Here we will use state.
# Examine the state variable above.
# and create one variable for on-going vs concluded projects.

ongoing_df = df[df["state"] == "live"]
    
concluded_df = df[df["state"] == "successful"]

# %%
# Objective 9.
# Examine on-going projects
ongoing_df
# Out:
#        backers_count                                              blurb  \
# 7695               5  RECORD AND PLAY EVERY SOUNDS IN A LOVELY DESKT...
# 8209             417  Designed for cities. Built for trails. Handcra...
# 8448              21  The portable, clean and green solution to dog ...
# 8693             740  A comedy about love, disability, and how famil...
# 8818               2  A new protective mask that has a fan built in ...
# 8906               3  This sequel will be ongoing story of Gabriel a...
# 9024              55  A deck of cards with a swinging, fashion-inspi...
# 9102             132                      An Art Book By Lewis Campbell
# 9274               9  multiplayer survival - story telling - mission...
# 9352             474  You like maps and fantasy ? This Atlas would f...
# 9409               2                              "angel , sweet angel"
# 9598              61  Automated, stylish microgreens grower designed...
# 9627             598  The 4 in 1 fast charging and data transfer cab...
# 9647              11  Introducing your Brand New Coffee Shop Experie...
# 9658             536     A tactical board game that fits in your pocket
# 9736            1057  Futuristic style meets function in a groundbre...
# 9795             165  Say Hello to FLEX&LOCK - A Safer & Fun Lunchbo...
# 9815            1207  A coming of age story set in a world devastate...
# 9866              54  An exciting fantasy series that brings you epi...
# 9892            2859  We are back - The original 2D/3D optical illus...
# 9935               3  Poems and images inspired by the geology of Te...
# 9960             167  Our new tail system features USB charging + po...
# 9988              71  The party game full of crazy concepts and play...
# 9996             157  A new collection of the award-winning Dunce-st...
# 10023             40  A fine-art photography book, a eulogy to paren...
# 10033              5  Own a piece of "Spearfishing & Scuba" history....
# 10075             11  Our goal, take eyewear to a new level! Our pro...
# 10120           1319  The collected edition of volume 1 of the hit w...
# 10133             12  Write your story in perfume with these niche f...
# 10147            104    The second installment of a new Sci-fi journey!
# 10181             66  100% plant-based ingredients. Better results, ...
# 10221           1891  A new series from Jeff Smith, creator of BONE ...
#
#       country    usd_pledged state
# 7695       FR    1054.630332  live
# 8209       US   89234.560000  live
# 8448       US    1024.000000  live
# 8693       US  111094.530000  live
# 8818       US     501.000000  live
# 8906       CA      16.991764  live
# 9024       US    3279.000000  live
# 9102       GB    8846.670087  live
# 9274       DE     451.950237  live
# 9352       FR   32868.523627  live
# 9409       MX       1.426629  live
# 9598       GB   16300.378958  live
# 9627       HK   23887.696164  live
# 9647       US    5601.000000  live
# 9658       GB    7283.386386  live
# 9736       US  246581.000000  live
# 9795       US   18061.000000  live
# 9815       US   52564.000000  live
# 9866       US   13230.000000  live
# 9892       GB  292264.770114  live
# 9935       GB      43.228831  live
# 9960       GB   43733.133515  live
# 9988       GB    1970.000698  live
# 9996       NO    4787.617043  live
# 10023      FR    3910.090743  live
# 10033      GB     382.717211  live
# 10075      US    2491.000000  live
# 10120      US   75554.000000  live
# 10133      NL    2158.444376  live
# 10147      US    1753.000000  live
# 10181      AU    8960.684519  live
# 10221      US  197282.000000  live

# %%
# Objective 10.
# Examine concluded projects
concluded_df
# Out:
#        backers_count                                              blurb  \
# 6091              15  Oy With The plushies Already makes crochet/ kn...
# 6092              13  Castle Elysium is the Sanctuary for two twin S...
# 6093             331  From Zero to Full-Stack Engineer. Build Web Ap...
# 6094             124  Bringing the love of comics back to a new gene...
# 6095             105        64 pages of adventures in the 18th Century!
# ...              ...                                                ...
# 10282            120  It's 1903. Cryptids threaten the security of t...
# 10283             28                          Hard enamel monster pins.
# 10285            120  A kick ass motivational enamel pin featuring t...
# 10286            495  An autobiographical comic that explores the in...
# 10287            353  Outstanding in every way, from design to finis...
#
#       country    usd_pledged       state
# 6091       US     626.000000  successful
# 6092       US     233.000000  successful
# 6093       AU   21549.699942  successful
# 6094       NZ    4957.598045  successful
# 6095       GB    2996.830599  successful
# ...       ...            ...         ...
# 10282      CA    2298.695235  successful
# 10283      GB     713.741584  successful
# 10285      GB    2774.202113  successful
# 10286      US   11872.000000  successful
# 10287      AU  181091.530902  successful
#
# [3025 rows x 5 columns]

# %%
# Objective 11.
# Use the above DataFrames to answer the following

# On-going average funding
ongoing_avg_funding = ongoing_df["usd_pledged"].mean()

# Concluded average funding
concluded_avg_funding = concluded_df["usd_pledged"].mean()

# On-going total backers
ongoing_total_backers = ongoing_df["backers_count"].sum()

# Concluded total backers
concluded_total_backers = concluded_df["backers_count"].sum()

# %%
# Objective 12.
print(f"The average funding for live projects: {ongoing_avg_funding:.3f}")
print(f"The average funding for successful projects: {concluded_avg_funding:.3f}")

print(f"The total number of backers for live projects: {ongoing_total_backers}")
print(f"The total number of backers for successful projects: {concluded_total_backers}")
# Out:
# The average funding for live projects: 39599.138
# The average funding for successful projects: 23063.188
# The total number of backers for live projects: 12254
# The total number of backers for successful projects: 791802

# %%
# Objective 13.
# Using pandas helper methods, plot historgrams for each country.
# Do not change the order of these

concluded_df["country"].hist()
ongoing_df["country"].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Congratulations! You've completed this assignment 🎉
