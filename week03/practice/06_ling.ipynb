# %%
import numpy as np
import pandas as pd
import pandas_datareader as pdr
from sklearn.linear_model import LinearRegression
import statsmodels.api as ols

# %%
tickers = ["AAPL", "TWTR", "IBM", "MSFT", "^GSPC"]
stocks_price = pdr.get_data_yahoo(tickers, "2020-01-01")["Adj Close"]
stocks_price.head()
# Out:
# Symbols          AAPL       TWTR         IBM        MSFT        ^GSPC
# Date
# 2020-01-02  74.096458  32.299999  124.142921  157.903473  3257.850098
# 2020-01-03  73.376091  31.520000  123.152855  155.937286  3234.850098
# 2020-01-06  73.960770  31.639999  122.932838  156.340378  3246.280029
# 2020-01-07  73.612930  32.540001  123.015350  154.914886  3237.179932
# 2020-01-08  74.797081  33.049999  124.042084  157.382446  3253.050049

# %%
log_returns = np.log(stocks_price / stocks_price.shift())
log_returns
# Out:
# Symbols         AAPL      TWTR       IBM      MSFT     ^GSPC
# Date
# 2020-01-02       NaN       NaN       NaN       NaN       NaN
# 2020-01-03 -0.009770 -0.024445 -0.008007 -0.012530 -0.007085
# 2020-01-06  0.007937  0.003800 -0.001788  0.002582  0.003527
# 2020-01-07 -0.004714  0.028048  0.000671 -0.009160 -0.002807
# 2020-01-08  0.015958  0.015551  0.008312  0.015803  0.004890
# ...              ...       ...       ...       ...       ...
# 2021-10-25 -0.000336 -0.002091 -0.001879 -0.003337  0.004737
# 2021-10-26  0.004564 -0.011009 -0.004004  0.006405  0.001818
# 2021-10-27 -0.003153 -0.114026 -0.015537  0.041252 -0.005064
# 2021-10-28  0.024684 -0.009533  0.005338  0.003645  0.009781
# 2021-10-29 -0.018322 -0.013911 -0.005898  0.022167  0.001947
#
# [462 rows x 5 columns]

# %%
X = log_returns["AAPL"].dropna().values.reshape(-1, 1)
y = log_returns["^GSPC"].dropna().values

# %%
ling_model = LinearRegression()
ling_model.fit(X, y)
# Out:
# LinearRegression()

# %%
ling_model.intercept_, ling_model.coef_
# Out:
# (-0.00011805304419945813, array([0.56905972]))

# %%
y_hat = ling_model.predict(X)

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x=X.flatten(),
                         y=y,
                         name="Log of Returns",
                         mode="markers",
                         marker=dict(color="Blue",
                                     opacity=0.5,
                                     line=dict(width=2,
                                               color="Black"))))
fig.add_trace(go.Scatter(x=X.flatten(),
                         y=y_hat,
                         name="Linear Model",
                         mode="lines"))

fig.update_layout(height=1000,
                  width=1000,
                  title="SPC500 vs APPL<br>" +
                        f"alph = {ling_model.intercept_}<br>" +
                        f"beta = {ling_model.coef_[0]}<br>" + 
                        f"r = {ling_model.score(X, y)}",
                  xaxis_title="AAPL",
                  yaxis_title="SPC500",
                  font=dict(family="Courier New, monospace",
                            size=15,))

fig.show()
# Out:
# <div>                            <div id="f101e560-ce7b-4efc-ac91-4cd8b9d09ff2" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f101e560-ce7b-4efc-ac91-4cd8b9d09ff2")) {                    Plotly.newPlot(                        "f101e560-ce7b-4efc-ac91-4cd8b9d09ff2",                        [{"marker":{"color":"Blue","line":{"color":"Black","width":2},"opacity":0.5},"mode":"markers","name":"Log of Returns","type":"scatter","x":[-0.009769589852349367,0.007936665901541264,-0.0047141191113423365,0.015958166370904404,0.021018496541166283,0.002257926220083557,0.021139492385715695,-0.013595182727199239,-0.004294781813658404,0.012448642516683104,0.011010199935504223,-0.006799991796153313,0.0035631426065608272,0.004804369503515183,-0.0028863215563581152,-0.029846265289780592,0.02789658048930803,0.020716367943384186,-0.0014500817681033643,-0.04535180489456731,-0.0027500358396656517,0.03248043859013002,0.008121302170619148,0.011628971147247185,-0.013685874834168393,0.0047383473538883,-0.006051668693958166,0.02347019912696788,-0.007146545327423386,0.00024622392286184527,-0.01848023179414743,0.014378828116907036,-0.010311867160485322,-0.02289515217778329,-0.048665574218831255,-0.03445924713829612,0.01573924530519918,-0.06760268429442562,-0.0005850292153973483,0.08901833334760396,-0.03227454903774443,0.04534096517500608,-0.03297488991125565,-0.013368869226057853,-0.0823953857446891,0.06954626415639335,-0.03534800407664832,-0.10397769030324841,0.11315746992410632,-0.13770805388179871,0.043030735010751865,-0.024784586614239382,-0.007691543977123455,-0.06559024232356377,-0.02147305954193731,0.0956058769518083,-0.005523895214167215,0.05128522999750199,-0.042283856458364834,0.028138284346279664,-0.00204277646372876,-0.054051873379234915,0.01654900302197709,-0.01447570615680367,0.08363993371630264,-0.01164984490043971,0.02527259194096878,0.007190058800575953,0.019437526413352283,0.04926939336061365,-0.009169228079722267,0.007914240674329595,-0.013661487337566332,-0.0209751760388508,-0.03139815522819319,0.028396414670671215,-0.003883036527820808,0.028460785986677783,0.0007067079563129829,-0.016342236203019413,0.032317151147162104,0.02087679233616628,-0.01623039664658479,0.014049756355663407,0.014897255719527401,0.010264427812483524,0.010291789363320123,0.02352282725198938,0.015612824551191324,-0.011493917012640676,-0.012147601150834964,0.006124453116340213,-0.005929545270682352,0.023287872553296483,-0.0057951751951751005,0.019261378601629846,-0.007483372524212577,0.006417838314662349,-0.006796638265421663,0.00434756025127518,0.0004399059664369265,-0.0009743585281123357,0.012222915117289833,0.00461861323465607,0.00548994586058258,-0.008649316431964706,0.028082881211724663,0.0058951101430869575,0.0310896775248827,0.025402028733291095,-0.04920121736379893,0.008596469295979568,0.012291423590726524,0.026157137229156108,-0.0013926988723622232,0.0003981994020127564,-0.005731090489042042,0.025827378333544565,0.021120088877221495,-0.01780960971408466,0.013188220441315433,-0.031207740538684345,0.022785044310634203,0.008313053088526434,-0.0018933233986501378,0.0,0.02639863646609343,-0.00310759101703791,0.023022982558000237,0.004291067386926256,0.0017477738999215667,-0.004623814005307669,0.016412972682527154,0.0068538269212523786,-0.012381432220890075,-0.002022138906362641,0.020854961155637612,-0.013897824968995645,0.0028053403693440535,-0.0465849763180554,-0.00248032130088191,0.023423862180716952,-0.01656394269008889,0.01898690996359659,0.012027549453138905,0.09956339681114652,0.02488548176587657,0.0066558728631561075,0.0036181930000672297,0.034294442458842375,-0.022998223887110984,0.014430235325609156,-0.030191148700343232,0.03269404306928086,0.01754272269062481,-0.0008916228094694187,-0.0026141892013716527,0.0082982745 ...

# %%
ling_model.score(X, y)
# Out:
# 0.651483879708859
